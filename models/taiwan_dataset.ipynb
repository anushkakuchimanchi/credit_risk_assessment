# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pylab as plt
import seaborn as sns

df=pd.read_excel(r"D:\credit_scoring\data\default of credit card clients.xls",header=1)
df.columns = [
            'ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE',
            'PAY_0', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6',
            'BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6',
            'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
            'default_payment_next_month'
        ]

# %%
df.drop(index=0,axis=0,inplace=True)
df.to_csv('taiwan_credit_card_dataset.csv', index=False)
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# 5          6      50000    1          1         2   37      0      0      0
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
#        PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 1          0  ...       3272       3455       3261         0      1000
# 2          0  ...      14331      14948      15549      1518      1500
# 3          0  ...      28314      28959      29547      2000      2019
# 4          0  ...      20940      19146      19131      2000     36681
# 5          0  ...      19394      19619      20024      2500      1815
# ...      ...  ...        ...        ...        ...       ...       ...
# 29995      0  ...      88004      31237      15980      8500     20000
# 29996     -1  ...       8979       5190          0      1837      3526
# 29997     -1  ...      20878      20582      19357         0         0
# 29998      0  ...      52774      11855      48944     85900      3409
# 29999      0  ...      36535      32428      15313      2078      1800
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default_payment_next_month
# 1          1000      1000         0      2000                           1
# 2          1000      1000      1000      5000                           0
# 3          1200      1100      1069      1000                           0
# 4         10000      9000       689       679                           0
# 5           657      1000      1000       800                           0
# ...         ...       ...       ...       ...                         ...
# 29995      5003      3047      5000      1000                           0
# 29996      8998       129         0         0                           0
# 29997     22000      4200      2000      3100                           1
# 29998      1178      1926     52964      1804                           1
# 29999      1430      1000      1000      1000                           1
#
# [29999 rows x 25 columns]

# %%
for col in df.columns:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
df.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  29999.000000    29999.000000  29999.000000  29999.000000  29999.000000
# mean   15001.000000   167489.238975      1.603720      1.853128      1.551885
# std     8660.109699   129747.029798      0.489132      0.790361      0.521969
# min        2.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7501.500000    50000.000000      1.000000      1.000000      1.000000
# 50%    15001.000000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.500000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  29999.000000  29999.000000  29999.000000  29999.000000  29999.000000
# mean      35.485883     -0.016767     -0.133838     -0.166172     -0.220641
# std        9.217819      1.123760      1.197143      1.196878      1.169149
# min       21.000000     -2.000000     -2.000000     -2.000000     -2.000000
# 25%       28.000000     -1.000000     -1.000000     -1.000000     -1.000000
# 50%       34.000000      0.000000      0.000000      0.000000      0.000000
# 75%       41.000000      0.000000      0.000000      0.000000      0.000000
# max       79.000000      8.000000      8.000000      8.000000      8.000000
#
#        ...      BILL_AMT4      BILL_AMT5      BILL_AMT6       PAY_AMT1  \
# count  ...   29999.000000   29999.000000   29999.000000   29999.000000
# mean   ...   43264.391113   40312.744725   38873.056169    5663.769292
# std    ...   64333.443473   60797.723604   59554.677258   16563.524146
# min    ... -170000.000000  -81334.000000 -339603.000000       0.000000
# 25%    ...    2328.000000    1763.500000    1256.000000    1000.000000
# 50%    ...   19052.000000   18105.000000   17074.000000    2100.000000
# 75%    ...   54509.000000   50196.000000   49200.500000    5006.000000
# max    ...  891586.000000  927171.000000  961664.000000  873552.000000
#
#            PAY_AMT2       PAY_AMT3       PAY_AMT4       PAY_AMT5  \
# count  2.999900e+04   29999.000000   29999.000000   29999.000000
# mean   5.921338e+03    5225.855695    4826.237741    4799.547618
# std    2.304123e+04   17607.229085   15666.396081   15278.535203
# min    0.000000e+00       0.000000       0.000000       0.000000
# 25%    8.330000e+02     390.000000     296.000000     253.500000
# 50%    2.009000e+03    1800.000000    1500.000000    1500.000000
# 75%    5.000000e+03    4505.000000    4013.500000    4032.000000
# max    1.684259e+06  896040.000000  621000.000000  426529.000000
#
#             PAY_AMT6  default_payment_next_month
# count   29999.000000                29999.000000
# mean     5215.676423                    0.221174
# std     17777.736580                    0.415044
# min         0.000000                    0.000000
# 25%       118.000000                    0.000000
# 50%      1500.000000                    0.000000
# 75%      4000.000000                    0.000000
# max    528666.000000                    1.000000
#
# [8 rows x 25 columns]

# %%
df.dtypes
# Out:
# ID                            int64
# LIMIT_BAL                     int64
# SEX                           int64
# EDUCATION                     int64
# MARRIAGE                      int64
# AGE                           int64
# PAY_0                         int64
# PAY_2                         int64
# PAY_3                         int64
# PAY_4                         int64
# PAY_5                         int64
# PAY_6                         int64
# BILL_AMT1                     int64
# BILL_AMT2                     int64
# BILL_AMT3                     int64
# BILL_AMT4                     int64
# BILL_AMT5                     int64
# BILL_AMT6                     int64
# PAY_AMT1                      int64
# PAY_AMT2                      int64
# PAY_AMT3                      int64
# PAY_AMT4                      int64
# PAY_AMT5                      int64
# PAY_AMT6                      int64
# default_payment_next_month    int64
# dtype: object

# %%
df.isna().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default_payment_next_month    0
# dtype: int64

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
# 5   6      50000    1          1         2   37      0      0      0      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
# 5  ...      19394      19619      20024      2500      1815       657
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default_payment_next_month
# 1      1000         0      2000                           1
# 2      1000      1000      5000                           0
# 3      1100      1069      1000                           0
# 4      9000       689       679                           0
# 5      1000      1000       800                           0
#
# [5 rows x 25 columns]

# %%
#df['SEX'].value_counts()
df['EDUCATION'].value_counts()
#df['MARRIAGE'].value_counts()
# Out:
# EDUCATION
# 2    14029
# 1    10585
# 3     4917
# 5      280
# 4      123
# 6       51
# 0       14
# Name: count, dtype: int64

# %% [markdown]
# feature engineering

# %%
pay_status_cols = ['PAY_0', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6']

# Calculate delay penalty score
delay_penalty = df[pay_status_cols].clip(0, 9).sum(axis=1)  # Sum all delays

# Convert to percentiles (this will spread out the scores)
df['payment_history'] = (1 - delay_penalty.rank(pct=True)).round(2)

# %%
df['avg_bill']=df[['BILL_AMT1','BILL_AMT2','BILL_AMT3','BILL_AMT4','BILL_AMT5','BILL_AMT6']].mean(axis=1)
df['credit_utilization_ratio']=(df['avg_bill']/df['LIMIT_BAL']).clip(upper=1)
df['credit_utilization_ratio']=pd.to_numeric(1-df['credit_utilization_ratio']).round(2)
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# 5          6      50000    1          1         2   37      0      0      0
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
#        PAY_4  ...  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# 1          0  ...         0      1000      1000      1000         0      2000
# 2          0  ...      1518      1500      1000      1000      1000      5000
# 3          0  ...      2000      2019      1200      1100      1069      1000
# 4          0  ...      2000     36681     10000      9000       689       679
# 5          0  ...      2500      1815       657      1000      1000       800
# ...      ...  ...       ...       ...       ...       ...       ...       ...
# 29995      0  ...      8500     20000      5003      3047      5000      1000
# 29996     -1  ...      1837      3526      8998       129         0         0
# 29997     -1  ...         0         0     22000      4200      2000      3100
# 29998      0  ...     85900      3409      1178      1926     52964      1804
# 29999      0  ...      2078      1800      1430      1000      1000      1000
#
#        default_payment_next_month  payment_history       avg_bill  \
# 1                               1             0.15    2846.166667
# 2                               0             0.67   16942.166667
# 3                               0             0.67   38555.666667
# 4                               0             0.67   18223.166667
# 5                               0             0.67   39685.666667
# ...                           ...              ...            ...
# 29995                           0             0.67  120891.500000
# 29996                           0             0.67    3530.333333
# 29997                           1             0.06   11749.333333
# 29998                           1             0.31   44435.166667
# 29999                           1             0.67   38479.000000
#
#        credit_utilization_ratio
# 1                          0.98
# 2                          0.81
# 3                          0.23
# 4                          0.64
# 5                          0.21
# ...                         ...
# 29995                      0.45
# 29996                      0.98
# 29997                      0.61
# 29998                      0.44
# 29999                      0.23
#
# [29999 rows x 28 columns]

# %%
bill_cols = ['BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6']
df['number_of_credit_accounts'] = ((df[bill_cols] > 0).sum(axis=1) / 6).round(2)
# Convert to percentile ranks - this worked great for payment_history
df['number_of_credit_accounts'] = df['number_of_credit_accounts'].rank(pct=True).round(2)

# %%
edu_map = {1: 0.85, 2: 0.8, 3: 0.75, 4: 0.70, 5: 0.7, 6: 0.7, 0: 0.7}
df['education_level'] = df['EDUCATION'].map(edu_map)
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# 5          6      50000    1          1         2   37      0      0      0
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
#        PAY_4  ...  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# 1          0  ...      1000      1000         0      2000
# 2          0  ...      1000      1000      1000      5000
# 3          0  ...      1200      1100      1069      1000
# 4          0  ...     10000      9000       689       679
# 5          0  ...       657      1000      1000       800
# ...      ...  ...       ...       ...       ...       ...
# 29995      0  ...      5003      3047      5000      1000
# 29996     -1  ...      8998       129         0         0
# 29997     -1  ...     22000      4200      2000      3100
# 29998      0  ...      1178      1926     52964      1804
# 29999      0  ...      1430      1000      1000      1000
#
#        default_payment_next_month  payment_history       avg_bill  \
# 1                               1             0.15    2846.166667
# 2                               0             0.67   16942.166667
# 3                               0             0.67   38555.666667
# 4                               0             0.67   18223.166667
# 5                               0             0.67   39685.666667
# ...                           ...              ...            ...
# 29995                           0             0.67  120891.500000
# 29996                           0             0.67    3530.333333
# 29997                           1             0.06   11749.333333
# 29998                           1             0.31   44435.166667
# 29999                           1             0.67   38479.000000
#
#        credit_utilization_ratio  number_of_credit_accounts  education_level
# 1                          0.98                       0.63             0.80
# 2                          0.81                       0.63             0.80
# 3                          0.23                       0.63             0.80
# 4                          0.64                       0.63             0.80
# 5                          0.21                       0.63             0.85
# ...                         ...                        ...              ...
# 29995                      0.45                       0.63             0.75
# 29996                      0.98                       0.21             0.75
# 29997                      0.61                       0.63             0.80
# 29998                      0.44                       0.21             0.75
# 29999                      0.23                       0.63             0.80
#
# [29999 rows x 30 columns]

# %%
age_factor = df['AGE'].apply(lambda x: min(1.0, (x - 18) / 30))
activity_factor = ((df[bill_cols] > 0).sum(axis=1) / 6)    
df['credit_history_length'] = (
    (age_factor * 0.7) + (activity_factor * 0.3)
).round(2)
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# 5          6      50000    1          1         2   37      0      0      0
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
#        PAY_4  ...  PAY_AMT4  PAY_AMT5  PAY_AMT6  default_payment_next_month  \
# 1          0  ...      1000         0      2000                           1
# 2          0  ...      1000      1000      5000                           0
# 3          0  ...      1100      1069      1000                           0
# 4          0  ...      9000       689       679                           0
# 5          0  ...      1000      1000       800                           0
# ...      ...  ...       ...       ...       ...                         ...
# 29995      0  ...      3047      5000      1000                           0
# 29996     -1  ...       129         0         0                           0
# 29997     -1  ...      4200      2000      3100                           1
# 29998      0  ...      1926     52964      1804                           1
# 29999      0  ...      1000      1000      1000                           1
#
#        payment_history       avg_bill  credit_utilization_ratio  \
# 1                 0.15    2846.166667                      0.98
# 2                 0.67   16942.166667                      0.81
# 3                 0.67   38555.666667                      0.23
# 4                 0.67   18223.166667                      0.64
# 5                 0.67   39685.666667                      0.21
# ...                ...            ...                       ...
# 29995             0.67  120891.500000                      0.45
# 29996             0.67    3530.333333                      0.98
# 29997             0.06   11749.333333                      0.61
# 29998             0.31   44435.166667                      0.44
# 29999             0.67   38479.000000                      0.23
#
#        number_of_credit_accounts  education_level  credit_history_length
# 1                           0.63             0.80                   0.49
# 2                           0.63             0.80                   0.67
# 3                           0.63             0.80                   0.74
# 4                           0.63             0.80                   1.00
# 5                           0.63             0.85                   0.74
# ...                          ...              ...                    ...
# 29995                       0.63             0.75                   0.79
# 29996                       0.21             0.75                   0.83
# 29997                       0.63             0.80                   0.74
# 29998                       0.21             0.75                   0.79
# 29999                       0.63             0.80                   0.95
#
# [29999 rows x 31 columns]

# %%
df['weighted_score'] = (
    df['payment_history'] * 0.35 +
    df['credit_utilization_ratio'] * 0.30 +
    df['credit_history_length'] * 0.15 +      # New factor
    df['number_of_credit_accounts'] * 0.10 +
    df['education_level'] * 0.10
)
df['credit_score'] = df['weighted_score'] * 700 + 300
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# 5          6      50000    1          1         2   37      0      0      0
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
#        PAY_4  ...  PAY_AMT6  default_payment_next_month  payment_history  \
# 1          0  ...      2000                           1             0.15
# 2          0  ...      5000                           0             0.67
# 3          0  ...      1000                           0             0.67
# 4          0  ...       679                           0             0.67
# 5          0  ...       800                           0             0.67
# ...      ...  ...       ...                         ...              ...
# 29995      0  ...      1000                           0             0.67
# 29996     -1  ...         0                           0             0.67
# 29997     -1  ...      3100                           1             0.06
# 29998      0  ...      1804                           1             0.31
# 29999      0  ...      1000                           1             0.67
#
#             avg_bill  credit_utilization_ratio  number_of_credit_accounts  \
# 1        2846.166667                      0.98                       0.63
# 2       16942.166667                      0.81                       0.63
# 3       38555.666667                      0.23                       0.63
# 4       18223.166667                      0.64                       0.63
# 5       39685.666667                      0.21                       0.63
# ...              ...                       ...                        ...
# 29995  120891.500000                      0.45                       0.63
# 29996    3530.333333                      0.98                       0.21
# 29997   11749.333333                      0.61                       0.63
# 29998   44435.166667                      0.44                       0.21
# 29999   38479.000000                      0.23                       0.63
#
#        education_level  credit_history_length  weighted_score  credit_score
# 1                 0.80                   0.49          0.5630        694.10
# 2                 0.80                   0.67          0.7210        804.70
# 3                 0.80                   0.74          0.5575        690.25
# 4                 0.80                   1.00          0.7195        803.65
# 5                 0.85                   0.74          0.5565        689.55
# ...                ...                    ...             ...           ...
# 29995             0.75                   0.79          0.6260        738.20
# 29996             0.75                   0.83          0.7490        824.30
# 29997             0.80                   0.74          0.4580        620.60
# 29998             0.75                   0.79          0.4550        618.50
# 29999             0.80                   0.95          0.5890        712.30
#
# [29999 rows x 33 columns]

# %%
df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default_payment_next_month', 'payment_history', 'avg_bill',
#        'credit_utilization_ratio', 'number_of_credit_accounts',
#        'education_level', 'credit_history_length', 'weighted_score',
#        'credit_score'],
#       dtype='object')

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['credit_utilization_ratio'],bins=50,color="yellow")
plt.show()
# Out:
# C:\Users\Anushka\AppData\Local\Temp\ipykernel_1844\2204621859.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['credit_utilization_ratio'],bins=50,color="yellow")

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['AGE'],bins=50,color='red')
plt.title('Age Distribution')
plt.show()
# Out:
# C:\Users\Anushka\AppData\Local\Temp\ipykernel_1844\968508696.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['AGE'],bins=50,color='red')

# %%
numeric_data=df.select_dtypes(include=[np.number])
numeric_data.corr()
# Out:
#                                   ID  LIMIT_BAL       SEX  EDUCATION  \
# ID                          1.000000   0.026115  0.018545   0.039189
# LIMIT_BAL                   0.026115   1.000000  0.024787  -0.219159
# SEX                         0.018545   0.024787  1.000000   0.014227
# EDUCATION                   0.039189  -0.219159  0.014227   1.000000
# MARRIAGE                   -0.029142  -0.108184 -0.031361  -0.143461
# AGE                         0.018607   0.144672 -0.090843   0.175073
# PAY_0                      -0.030474  -0.271167 -0.057695   0.105359
# PAY_2                      -0.011113  -0.296337 -0.070824   0.121561
# PAY_3                      -0.018535  -0.286158 -0.066078   0.114030
# PAY_4                      -0.002774  -0.267493 -0.060156   0.108798
# PAY_5                      -0.022290  -0.249484 -0.055025   0.097534
# PAY_6                      -0.020358  -0.235265 -0.043970   0.082328
# BILL_AMT1                   0.019353   0.285414 -0.033625   0.023585
# BILL_AMT2                   0.017946   0.278298 -0.031167   0.018753
# BILL_AMT3                   0.024317   0.283219 -0.024546   0.013007
# BILL_AMT4                   0.040314   0.293971 -0.021862  -0.000447
# BILL_AMT5                   0.016668   0.295546 -0.016988  -0.007562
# BILL_AMT6                   0.016693   0.290373 -0.016716  -0.009095
# PAY_AMT1                    0.009723   0.195228 -0.000233  -0.037454
# PAY_AMT2                    0.008393   0.178403 -0.001385  -0.030037
# PAY_AMT3                    0.039135   0.210160 -0.008589  -0.039941
# PAY_AMT4                    0.007776   0.203235 -0.002221  -0.038216
# PAY_AMT5                    0.000634   0.217196 -0.001659  -0.040357
# PAY_AMT6                    0.002983   0.219589 -0.002758  -0.037198
# default_payment_next_month -0.013845  -0.153461 -0.040014   0.027996
# payment_history             0.027607   0.242950  0.036777  -0.040779
# avg_bill                    0.023684   0.302027 -0.025901   0.007754
# credit_utilization_ratio   -0.010749   0.387398  0.069067  -0.171438
# number_of_credit_accounts   0.017881  -0.083324 -0.029739   0.063834
# education_level            -0.037673   0.231085 -0.013622  -0.981832
# credit_history_length       0.026313   0.121941 -0.095882   0.183348
# weighted_score              0.016060   0.444042  0.046797  -0.125532
# credit_score                0.016060   0.444042  0.046797  -0.125532
#
#                             MARRIAGE       AGE     PAY_0     PAY_2     PAY_3  \
# ID                         -0.029142  0.018607 -0.030474 -0.011113 -0.018535
# LIMIT_BAL                  -0.108184  0.144672 -0.271167 -0.296337 -0.286158
# SEX                        -0.031361 -0.090843 -0.057695 -0.070824 -0.066078
# EDUCATION                  -0.143461  0.175073  0.105359  0.121561  0.114030
# MARRIAGE                    1.000000 -0.414232  0.019982  0.024264  0.032664
# AGE                        -0.414232  1.000000 -0.039376 -0.050078 -0.053079
# PAY_0                       0.019982 -0.039376  1.000000  0.672129  0.574322
# PAY_2                       0.024264 -0.050078  0.672129  1.000000  0.766640
# PAY_3                       0.032664 -0.053079  0.574322  0.766640  1.000000
# PAY_4                       0.033099 -0.049751  0.538913  0.662147  0.777355
# PAY_5                       0.035577 -0.053893  0.509565  0.622928  0.686771
# PAY_6                       0.034294 -0.048838  0.474685  0.575641  0.632677
# BILL_AMT1                  -0.023495  0.056214  0.187118  0.234939  0.208461
# BILL_AMT2                  -0.021625  0.054258  0.189909  0.235310  0.237283
# BILL_AMT3                  -0.024934  0.053684  0.179836  0.224199  0.227482
# BILL_AMT4                  -0.023368  0.051327  0.179176  0.222290  0.227190
# BILL_AMT5                  -0.025417  0.049319  0.180685  0.221401  0.225133
# BILL_AMT6                  -0.021230  0.047587  0.177030  0.219455  0.222315
# PAY_AMT1                   -0.005991  0.026133 -0.079253 -0.080685  0.001287
# PAY_AMT2                   -0.008101  0.021776 -0.070091 -0.058980 -0.066799
# PAY_AMT3                   -0.003552  0.029236 -0.070547 -0.055887 -0.053318
# PAY_AMT4                   -0.012670  0.021367 -0.063990 -0.046843 -0.046074
# PAY_AMT5                   -0.001216  0.022838 -0.058174 -0.037076 -0.035871
# PAY_AMT6                   -0.006651  0.019466 -0.058659 -0.036485 -0.035868
# default_payment_next_month -0.024275  0.013969  0.324718  0.263469  0.235312
# payment_history             0.000159  0.022151 -0.646233 -0.547425 -0.547307
# avg_bill                   -0.024532  0.054954  0.191856  0.238238  0.235948
# credit_utilization_ratio   -0.053386  0.044497 -0.417982 -0.503219 -0.493269
# number_of_credit_accounts   0.020684 -0.025732  0.180110  0.413451  0.442993
# education_level             0.149130 -0.182448 -0.112586 -0.129698 -0.122431
# credit_history_length      -0.397123  0.899456  0.004684  0.106435  0.121987
# weighted_score             -0.114820  0.225605 -0.662483 -0.607776 -0.592453
# credit_score               -0.114820  0.225605 -0.662483 -0.607776 -0.592453
#
#                                PAY_4  ...  PAY_AMT6  \
# ID                         -0.002774  ...  0.002983
# LIMIT_BAL                  -0.267493  ...  0.219589
# SEX                        -0.060156  ... -0.002758
# EDUCATION                   0.108798  ... -0.037198
# MARRIAGE                    0.033099  ... -0.006651
# AGE                        -0.049751  ...  0.019466
# PAY_0                       0.538913  ... -0.058659
# PAY_2                       0.662147  ... -0.036485
# PAY_3                       0.777355  ... -0.035868
# PAY_4                       1.000000  ... -0.026572
# PAY_5                       0.819839  ... -0.023043
# PAY_6                       0.716448  ... -0.025315
# BILL_AMT1                   0.202801  ...  0.179336
# BILL_AMT2                   0.225805  ...  0.174251
# BILL_AMT3                   0.244972  ...  0.182321
# BILL_AMT4                   0.245906  ...  0.177632
# BILL_AMT5                   0.242891  ...  0.164179
# BILL_AMT6                   0.239143  ...  0.115489
# PAY_AMT1                   -0.009370  ...  0.185733
# PAY_AMT2                   -0.001949  ...  0.157632
# PAY_AMT3                   -0.069242  ...  0.162738
# PAY_AMT4                   -0.043469  ...  0.157831
# PAY_AMT5                   -0.033597  ...  0.154893
# PAY_AMT6                   -0.026572  ...  1.000000
# default_payment_next_month  0.216670  ... -0.053168
# payment_history            -0.501386  ...  0.078697
# avg_bill                    0.244550  ...  0.175303
# credit_utilization_ratio   -0.494049  ...  0.010589
# number_of_credit_accounts   0.489483  ...  0.050721
# education_level            -0.116536  ...  0.044059
# credit_history_length       0.143507  ...  0.048153
# weighted_score             -0.553649  ...  0.073870
# credit_score               -0.553649  ...  0.073870
#
#                             default_payment_next_month  payment_history  \
# ID                                           -0.013845         0.027607
# LIMIT_BAL                                    -0.153461         0.242950
# SEX                                          -0.040014         0.036777
# EDUCATION                                     0.027996        -0.040779
# MARRIAGE                                     -0.024275         0.000159
# AGE                                           0.013969         0.022151
# PAY_0                                         0.324718        -0.646233
# PAY_2                                         0.263469        -0.547425
# PAY_3                                         0.235312        -0.547307
# PAY_4                                         0.216670        -0.501386
# PAY_5                                         0.204265        -0.464105
# PAY_6                                         0.186977        -0.457720
# BILL_AMT1                                    -0.019605         0.064352
# BILL_AMT2                                    -0.014154         0.046601
# BILL_AMT3                                    -0.014035         0.034320
# BILL_AMT4                                    -0.010115         0.017561
# BILL_AMT5                                    -0.006719         0.001789
# BILL_AMT6                                    -0.005332        -0.000825
# PAY_AMT1                                     -0.072913         0.091433
# PAY_AMT2                                     -0.058568         0.077826
# PAY_AMT3                                     -0.056235         0.084470
# PAY_AMT4                                     -0.056812         0.080671
# PAY_AMT5                                     -0.055107         0.087650
# PAY_AMT6                                     -0.053168         0.078697
# default_payment_next_month                    1.000000        -0.390139
# payment_history                              -0.390139         1.000000
# avg_bill                                     -0.012649         0.030627
# credit_utilization_ratio                     -0.117590         0.194456
# number_of_credit_accounts                     0.012661        -0.047678
# education_level                              -0.033831         0.050017
# credit_history_length                         0.002480         0.020312
# weighted_score                               -0.316656         0.736589
# credit_score                                 -0.316656         0.736589
#
#                             avg_bill  credit_utilization_ratio  \
# ID                          0.023684                 -0.010749
# LIMIT_BAL                   0.302027                  0.387398
# SEX                        -0.025901                  0.069067
# EDUCATION                   0.007754                 -0.171438
# MARRIAGE                   -0.024532                 -0.053386
# AGE                         0.054954                  0.044497
# PAY_0                       0.191856                 -0.417982
# PAY_2                       0.238238                 -0.503219
# PAY_3                       0.235948                 -0.493269
# PAY_4                       0.244550                 -0.494049
# PAY_5                       0.257570                 -0.494459
# PAY_6                       0.263296                 -0.487029
# BILL_AMT1                   0.940100                 -0.509293
# BILL_AMT2                   0.961177                 -0.534360
# BILL_AMT3                   0.961958                 -0.536823
# BILL_AMT4                   0.964500                 -0.533462
# BILL_AMT5                   0.951675                 -0.521151
# BILL_AMT6                   0.928719                 -0.509597
# PAY_AMT1                    0.230054                 -0.046046
# PAY_AMT2                    0.187392                 -0.022805
# PAY_AMT3                    0.210391                 -0.015324
# PAY_AMT4                    0.192825                 -0.016247
# PAY_AMT5                    0.193004                 -0.010883
# PAY_AMT6                    0.175303                  0.010589
# default_payment_next_month -0.012649                 -0.117590
# payment_history             0.030627                  0.194456
# avg_bill                    1.000000                 -0.550935
# credit_utilization_ratio   -0.550935                  1.000000
# number_of_credit_accounts   0.331327                 -0.470095
# education_level            -0.001682                  0.176139
# credit_history_length       0.167433                 -0.112647
# weighted_score             -0.293332                  0.747061
# credit_score               -0.293332                  0.747061
#
#                             number_of_credit_accounts  education_level  \
# ID                                           0.017881        -0.037673
# LIMIT_BAL                                   -0.083324         0.231085
# SEX                                         -0.029739        -0.013622
# EDUCATION                                    0.063834        -0.981832
# MARRIAGE                                     0.020684         0.149130
# AGE                                         -0.025732        -0.182448
# PAY_0                                        0.180110        -0.112586
# PAY_2                                        0.413451        -0.129698
# PAY_3                                        0.442993        -0.122431
# PAY_4                                        0.489483        -0.116536
# PAY_5                                        0.519681        -0.104103
# PAY_6                                        0.536472        -0.089000
# BILL_AMT1                                    0.287357        -0.016602
# BILL_AMT2                                    0.308508        -0.011985
# BILL_AMT3                                    0.315386        -0.006719
# BILL_AMT4                                    0.328296         0.006126
# BILL_AMT5                                    0.328608         0.012434
# BILL_AMT6                                    0.330316         0.012642
# PAY_AMT1                                     0.086571         0.041086
# PAY_AMT2                                     0.053214         0.032791
# PAY_AMT3                                     0.069320         0.044291
# PAY_AMT4                                     0.066172         0.040947
# PAY_AMT5                                     0.076610         0.045136
# PAY_AMT6                                     0.050721         0.044059
# default_payment_next_month                   0.012661        -0.033831
# payment_history                             -0.047678         0.050017
# avg_bill                                     0.331327        -0.001682
# credit_utilization_ratio                    -0.470095         0.176139
# number_of_credit_accounts                    1.000000        -0.069983
# education_level                             -0.069983         1.000000
# credit_history_length                        0.319267        -0.192088
# weighted_score                              -0.147440         0.132134
# credit_score                                -0.147440         0.132134
#
#                             credit_history_length  weighted_score  \
# ID                                       0.026313        0.016060
# LIMIT_BAL                                0.121941        0.444042
# SEX                                     -0.095882        0.046797
# EDUCATION                                0.183348       -0.125532
# MARRIAGE                                -0.397123       -0.114820
# AGE                                      0.899456        0.225605
# PAY_0                                    0.004684       -0.662483
# PAY_2                                    0.106435       -0.607776
# PAY_3                                    0.121987       -0.592453
# PAY_4                                    0.143507       -0.553649
# PAY_5                                    0.148334       -0.525616
# PAY_6                                    0.152306       -0.512582
# BILL_AMT1                                0.153801       -0.253160
# BILL_AMT2                                0.159659       -0.277253
# BILL_AMT3                                0.162440       -0.284583
# BILL_AMT4                                0.163217       -0.289662
# BILL_AMT5                                0.160552       -0.290535
# BILL_AMT6                                0.156767       -0.284268
# PAY_AMT1                                 0.067396        0.050081
# PAY_AMT2                                 0.054179        0.050563
# PAY_AMT3                                 0.066232        0.065285
# PAY_AMT4                                 0.059170        0.060285
# PAY_AMT5                                 0.058572        0.069945
# PAY_AMT6                                 0.048153        0.073870
# default_payment_next_month               0.002480       -0.316656
# payment_history                          0.020312        0.736589
# avg_bill                                 0.167433       -0.293332
# credit_utilization_ratio                -0.112647        0.747061
# number_of_credit_accounts                0.319267       -0.147440
# education_level                         -0.192088        0.132134
# credit_history_length                    1.000000        0.185477
# weighted_score                           0.185477        1.000000
# credit_score                             0.185477        1.000000
#
#                             credit_score
# ID                              0.016060
# LIMIT_BAL                       0.444042
# SEX                             0.046797
# EDUCATION                      -0.125532
# MARRIAGE                       -0.114820
# AGE                             0.225605
# PAY_0                          -0.662483
# PAY_2                          -0.607776
# PAY_3                          -0.592453
# PAY_4                          -0.553649
# PAY_5                          -0.525616
# PAY_6                          -0.512582
# BILL_AMT1                      -0.253160
# BILL_AMT2                      -0.277253
# BILL_AMT3                      -0.284583
# BILL_AMT4                      -0.289662
# BILL_AMT5                      -0.290535
# BILL_AMT6                      -0.284268
# PAY_AMT1                        0.050081
# PAY_AMT2                        0.050563
# PAY_AMT3                        0.065285
# PAY_AMT4                        0.060285
# PAY_AMT5                        0.069945
# PAY_AMT6                        0.073870
# default_payment_next_month     -0.316656
# payment_history                 0.736589
# avg_bill                       -0.293332
# credit_utilization_ratio        0.747061
# number_of_credit_accounts      -0.147440
# education_level                 0.132134
# credit_history_length           0.185477
# weighted_score                  1.000000
# credit_score                    1.000000
#
# [33 rows x 33 columns]

# %%
plt.figure(figsize=(10,6))
sns.heatmap(numeric_data.corr(),annot=True)
plt.show()

# %%
def outliers(df):
    for i in df.columns:
        if df[i].dtype=='int64' or df[i].dtype=='float64':
            sns.boxplot(df[i])
            plt.show()

# %%
outliers(df)

# %%
# Check the distribution of your current payment_history
print("Current payment_history distribution:")
print(df['payment_history'].value_counts().head(10))
print(f"\nRange: {df['payment_history'].min()} to {df['payment_history'].max()}")

# Check the raw payment status data
pay_status_cols = ['PAY_0', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6']
print("\nPayment status distribution:")
for col in pay_status_cols:
    print(f"{col}: {df[col].value_counts().head(3).to_dict()}")
# Out:
# Current payment_history distribution:
# payment_history
# 0.67    19931
# 0.23     2764
# 0.31     1666
# 0.15     1032
# 0.18      747
# 0.10      627
# 0.03      604
# 0.07      515
# 0.12      484
# 0.09      389
# Name: count, dtype: int64
#
# Range: 0.0 to 0.67
#
# Payment status distribution:
# PAY_0: {0: 14737, -1: 5686, 1: 3688}
# PAY_2: {0: 15730, -1: 6050, 2: 3926}
# PAY_3: {0: 15764, -1: 5937, -2: 4085}
# PAY_4: {0: 16455, -1: 5686, -2: 4348}
# PAY_5: {0: 16947, -1: 5539, -2: 4545}
# PAY_6: {0: 16286, -1: 5740, -2: 4894}

# %%
def numb_outliers(df):
    for i in df.columns:
        if df[i].dtype=='float64' or df[i].dtype=='int64':
            q1=df[i].quantile(.25)
            q3=df[i].quantile(.75)
            iqr=q3-q1
            ub=q3+1.5*iqr
            lb=q1-1.5*iqr
            print('The number of outliers in',i,'is',df[(df[i]>ub) | (df[i]<lb)][i].count())

numb_outliers(df)
# Out:
# The number of outliers in ID is 0
# The number of outliers in LIMIT_BAL is 167
# The number of outliers in SEX is 0
# The number of outliers in EDUCATION is 454
# The number of outliers in MARRIAGE is 0
# The number of outliers in AGE is 272
# The number of outliers in PAY_0 is 3129
# The number of outliers in PAY_2 is 4409
# The number of outliers in PAY_3 is 4209
# The number of outliers in PAY_4 is 3508
# The number of outliers in PAY_5 is 2968
# The number of outliers in PAY_6 is 3079
# The number of outliers in BILL_AMT1 is 2400
# The number of outliers in BILL_AMT2 is 2395
# The number of outliers in BILL_AMT3 is 2469
# The number of outliers in BILL_AMT4 is 2622
# The number of outliers in BILL_AMT5 is 2725
# The number of outliers in BILL_AMT6 is 2693
# The number of outliers in PAY_AMT1 is 2745
# The number of outliers in PAY_AMT2 is 2714
# The number of outliers in PAY_AMT3 is 2598
# The number of outliers in PAY_AMT4 is 2994
# The number of outliers in PAY_AMT5 is 2946
# The number of outliers in PAY_AMT6 is 2958
# The number of outliers in default_payment_next_month is 6635
# The number of outliers in payment_history is 0
# The number of outliers in avg_bill is 2575
# The number of outliers in credit_utilization_ratio is 0
# The number of outliers in number_of_credit_accounts is 0
# The number of outliers in education_level is 468
# The number of outliers in credit_history_length is 0
# The number of outliers in weighted_score is 0
# The number of outliers in credit_score is 0

# %%
df['target'] = df['default_payment_next_month'].map({0: 0, 1: 1})
df['target'] = df['target'].astype(int)

y = df['target']
print(f"New target dtype: {y.dtype}")
print(f"Value counts:\n{y.value_counts()}")

x = df[['payment_history', 
        'credit_utilization_ratio', 
        'credit_history_length', 
        'number_of_credit_accounts', 
        'education_level']]
print(x)
# Out:
# New target dtype: int64
# Value counts:
# target
# 0    23364
# 1     6635
# Name: count, dtype: int64
#        payment_history  credit_utilization_ratio  credit_history_length  \
# 1                 0.15                      0.98                   0.49
# 2                 0.67                      0.81                   0.67
# 3                 0.67                      0.23                   0.74
# 4                 0.67                      0.64                   1.00
# 5                 0.67                      0.21                   0.74
# ...                ...                       ...                    ...
# 29995             0.67                      0.45                   0.79
# 29996             0.67                      0.98                   0.83
# 29997             0.06                      0.61                   0.74
# 29998             0.31                      0.44                   0.79
# 29999             0.67                      0.23                   0.95
#
#        number_of_credit_accounts  education_level
# 1                           0.63             0.80
# 2                           0.63             0.80
# 3                           0.63             0.80
# 4                           0.63             0.80
# 5                           0.63             0.85
# ...                          ...              ...
# 29995                       0.63             0.75
# 29996                       0.21             0.75
# 29997                       0.63             0.80
# 29998                       0.21             0.75
# 29999                       0.63             0.80
#
# [29999 rows x 5 columns]

# %%
from sklearn.model_selection import cross_val_score,train_test_split
x_train,x_temp,y_train,y_temp=train_test_split(x,y,test_size=0.4,stratify=y)
x_val, x_test, y_val, y_test = train_test_split(x_temp, y_temp, test_size=0.5, stratify=y_temp)
x_test
y
# Out:
# 1        1
# 2        0
# 3        0
# 4        0
# 5        0
#         ..
# 29995    0
# 29996    0
# 29997    1
# 29998    1
# 29999    1
# Name: target, Length: 29999, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
classifier=LogisticRegression()

# %%
from sklearn.model_selection import GridSearchCV

# Penalize misclassifying defaults more heavily
param_grid_weighted = {
    'C': [0.1, 1, 10],
    'class_weight': [None, 'balanced', {0: 1, 1: 3}],  # Give more weight to defaults
    'penalty': ['l2']
}

classifier_g= GridSearchCV(
    LogisticRegression(random_state=42, max_iter=1000),
    param_grid_weighted,
    scoring='f1',  # Focus on F1 instead of accuracy
    cv=5
)

# %%
classifier_g.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=LogisticRegression(max_iter=1000, random_state=42),
#              param_grid={'C': [0.1, 1, 10],
#                          'class_weight': [None, 'balanced', {0: 1, 1: 3}],
#                          'penalty': ['l2']},
#              scoring='f1')

# %%
classifier_g.best_params_
# Out:
# {'C': 1, 'class_weight': {0: 1, 1: 3}, 'penalty': 'l2'}

# %%
y_pred=classifier_g.predict(x_test)
y_test==y_pred
# Out:
# 20350     True
# 11251    False
# 8897     False
# 4490      True
# 2894      True
#          ...
# 29222    False
# 20143     True
# 23370     True
# 9584      True
# 1639      True
# Name: target, Length: 6000, dtype: bool

# %%
val_pred=classifier_g.predict(x_val)
y_val==val_pred
# Out:
# 29875    True
# 12702    True
# 28120    True
# 12516    True
# 14312    True
#          ...
# 13684    True
# 27674    True
# 28329    True
# 13803    True
# 7281     True
# Name: target, Length: 6000, dtype: bool

# %%
from sklearn.metrics import classification_report, confusion_matrix,roc_curve,roc_auc_score,precision_recall_curve, accuracy_score,precision_score,recall_score,f1_score
print(classification_report(y_test,classifier_g.predict(x_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.76      0.82      4673
#            1       0.43      0.63      0.51      1327
#
#     accuracy                           0.73      6000
#    macro avg       0.65      0.70      0.66      6000
# weighted avg       0.78      0.73      0.75      6000

# %%
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
import xgboost as xgb
from sklearn.metrics import classification_report, roc_auc_score

# XGBoost with class weighting
xgb_model = xgb.XGBClassifier(
    random_state=42,
    scale_pos_weight=6.0,  # Auto balance
    max_depth=6,
    learning_rate=0.1,
    n_estimators=100
)

xgb_model.fit(x_train, y_train)

# Evaluate
y_pred_xgb = xgb_model.predict(x_test)
y_pred_proba_xgb = xgb_model.predict_proba(x_test)[:, 1]

print("XGBoost Results:")
print(f"ROC-AUC: {roc_auc_score(y_test, y_pred_proba_xgb):.4f}")
print(classification_report(y_test, y_pred_xgb))
# Out:
# XGBoost Results:
# ROC-AUC: 0.7431
#               precision    recall  f1-score   support
#
#            0       0.89      0.58      0.70      4673
#            1       0.34      0.76      0.47      1327
#
#     accuracy                           0.62      6000
#    macro avg       0.62      0.67      0.58      6000
# weighted avg       0.77      0.62      0.65      6000

# %%
# Use your existing model but change threshold
y_pred_proba = classifier_g.predict_proba(x_test)[:, 1]

# Find optimal threshold
from sklearn.metrics import precision_recall_curve
import matplotlib.pyplot as plt

precision, recall, thresholds = precision_recall_curve(y_test, y_pred_proba)

# Plot precision-recall curve
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, marker='.')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.show()

# Try different thresholds
print("Threshold optimization:")
for threshold in [0.2, 0.25, 0.3, 0.35, 0.4]:
    y_pred_thresh = (y_pred_proba >= threshold).astype(int)
    from sklearn.metrics import precision_score, recall_score, f1_score
    
    precision_1 = precision_score(y_test, y_pred_thresh)
    recall_1 = recall_score(y_test, y_pred_thresh)
    f1_1 = f1_score(y_test, y_pred_thresh)
    
    print(f"Threshold {threshold}: Precision={precision_1:.3f}, Recall={recall_1:.3f}, F1={f1_1:.3f}")
# Out:
# Threshold optimization:
# Threshold 0.2: Precision=0.221, Recall=1.000, F1=0.362
# Threshold 0.25: Precision=0.257, Recall=0.899, F1=0.400
# Threshold 0.3: Precision=0.331, Recall=0.746, F1=0.458
# Threshold 0.35: Precision=0.419, Recall=0.637, F1=0.506
# Threshold 0.4: Precision=0.428, Recall=0.631, F1=0.510

# %%
# Install if needed: pip install imbalanced-learn
from imblearn.over_sampling import SMOTE
from sklearn.linear_model import LogisticRegression

# Apply SMOTE to training data only
smote = SMOTE(random_state=42)
x_train_smote, y_train_smote = smote.fit_resample(x_train, y_train)

print(f"Original training set: {y_train.value_counts().to_dict()}")
print(f"After SMOTE: {pd.Series(y_train_smote).value_counts().to_dict()}")

# Train on balanced data
lr_smote = LogisticRegression(random_state=42, max_iter=1000)
lr_smote.fit(x_train_smote, y_train_smote)

# Test on original test set
y_pred_smote = lr_smote.predict(x_test)
print("SMOTE + Logistic Regression Results:")
print(classification_report(y_test, y_pred_smote))
# Out:
# Original training set: {0: 14018, 1: 3981}
# After SMOTE: {0: 14018, 1: 14018}
# SMOTE + Logistic Regression Results:
#               precision    recall  f1-score   support
#
#            0       0.88      0.76      0.82      4673
#            1       0.43      0.63      0.51      1327
#
#     accuracy                           0.73      6000
#    macro avg       0.65      0.70      0.66      6000
# weighted avg       0.78      0.73      0.75      6000

# %%
xgb_smote = xgb.XGBClassifier(
    random_state=42,
    max_depth=6,
    learning_rate=0.1,
    n_estimators=100
)

xgb_smote.fit(x_train_smote, y_train_smote)

# Test on original test set
y_pred_smote_xgb = xgb_smote.predict(x_test)
print("SMOTE + xgb:")
print(classification_report(y_test, y_pred_smote_xgb))
# Out:
# SMOTE + xgb:
#               precision    recall  f1-score   support
#
#            0       0.85      0.86      0.86      4673
#            1       0.49      0.48      0.48      1327
#
#     accuracy                           0.77      6000
#    macro avg       0.67      0.67      0.67      6000
# weighted avg       0.77      0.77      0.77      6000

# %%
# 1. Check feature importance - are any features really predictive?
feature_importance = xgb_model.feature_importances_
print("Top 10 most important features:")
for i in np.argsort(feature_importance)[-10:]:
    print(f"{x.columns[i]}: {feature_importance[i]:.4f}")

# 2. Analyze the "hard" positive cases
false_negatives_idx = (y_test == 1) & (y_pred == 0)
hard_positives = x_test[false_negatives_idx]
print(f"We're missing {hard_positives.shape[0]} out of {sum(y_test)} positives")

# 3. Check if there's any pattern in missed cases
print("Stats of missed positive cases:")
print(hard_positives.describe())
# Out:
# Top 10 most important features:
# credit_history_length: 0.0557
# education_level: 0.0688
# number_of_credit_accounts: 0.0824
# credit_utilization_ratio: 0.0878
# payment_history: 0.7052
# We're missing 491 out of 1327 positives
# Stats of missed positive cases:
#        payment_history  credit_utilization_ratio  credit_history_length  \
# count       491.000000                491.000000             491.000000
# mean          0.669267                  0.658473               0.654175
# std           0.016247                  0.355702               0.202532
# min           0.310000                  0.000000               0.120000
# 25%           0.670000                  0.310000               0.490000
# 50%           0.670000                  0.810000               0.640000
# 75%           0.670000                  0.990000               0.810000
# max           0.670000                  1.200000               1.000000
#
#        number_of_credit_accounts  education_level
# count                 491.000000       491.000000
# mean                    0.469022         0.807739
# std                     0.239385         0.036157
# min                     0.020000         0.700000
# 25%                     0.210000         0.800000
# 50%                     0.630000         0.800000
# 75%                     0.630000         0.850000
# max                     0.630000         0.850000

# %%
import shap
import matplotlib.pyplot as plt

# Initialize SHAP explainer for the XGBoost model
explainer = shap.TreeExplainer(xgb_smote)  # Replace with your trained model
shap_values = explainer.shap_values(x_test)

# Summary plot: shows global feature importance and distribution
shap.summary_plot(shap_values, x_test)

# %%
# Bar plot: ranks features by average absolute SHAP value
shap.summary_plot(shap_values, x_test, plot_type="bar")

# %%
# Create SHAP values (the correct way for TreeExplainer in newer versions)
explainer = shap.Explainer(xgb_model)  # Note: Use shap.Explainer, not TreeExplainer
shap_values = explainer(x_test)

# Waterfall plot for a single test sample
index = 0
shap.waterfall_plot(shap_values[index])
